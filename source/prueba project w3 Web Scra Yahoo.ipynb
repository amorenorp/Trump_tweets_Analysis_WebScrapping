# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import json

# %%
url = "https://es.finance.yahoo.com/quote/%5ENDX/history/"

# %%
response = requests.get(url)

# %%
soup = BeautifulSoup(response.content, 'html.parser')

# %%
soup = soup.select("table")

# %%
soup
# Out:
# [<table class="W(100%) M(0)" data-reactid="33" data-test="historical-prices"><thead data-reactid="34"><tr class="C($tertiaryColor) Fz(xs) Ta(end)" data-reactid="35"><th class="Ta(start) W(100px) Fw(400) Py(6px)" data-reactid="36"><span data-reactid="37">Fecha</span></th><th class="Fw(400) Py(6px)" data-reactid="38"><span data-reactid="39">Abrir</span></th><th class="Fw(400) Py(6px)" data-reactid="40"><span data-reactid="41">Máx.</span></th><th class="Fw(400) Py(6px)" data-reactid="42"><span data-reactid="43">Mín.</span></th><th class="Fw(400) Py(6px)" data-reactid="44"><span data-reactid="45">Cierre*</span></th><th class="Fw(400) Py(6px)" data-reactid="46"><span data-reactid="47">Cierre ajus.**</span></th><th class="Fw(400) Py(6px)" data-reactid="48"><span data-reactid="49">Volumen</span></th></tr></thead><tbody data-reactid="50"><tr class="BdT Bdc($seperatorColor) Ta(end) Fz(s) Whs(nw)" data-reactid="51"><td class="Py(10px) Ta(start) Pend(10px)" data-reactid="52"><span data-reactid=
# ...
