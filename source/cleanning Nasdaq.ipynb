# %%
import pandas as pd
import datetime
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
def descargaclean(archivo_nasdaq):
    
    data = pd.read_csv(archivo_nasdaq)
    df = pd.DataFrame(data)
    df["crecimiento"] = df["Close"]-df["Open"]
    df["%"]= (df["crecimiento"]*100)/df["Close"]
    df = df[["Date","Open","Close","crecimiento","%"]]
    df.to_csv('nasdaq_clean.csv', index=False,)

    return ".csv guardado"

# %% [markdown]
# ### Importar el .csv descargado con `Selenium`

# %%
descargaclean("^IXIC (5).csv")
# Out:
# '.csv guardado'

# %%
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#          Date         Open         High          Low        Close  \
# 0  2016-02-01  4587.589844  4636.930176  4565.370117  4620.370117
# 1  2016-02-02  4588.689941  4589.899902  4503.120117  4516.950195
# 2  2016-02-03  4543.819824  4547.319824  4424.470215  4504.240234
# 3  2016-02-04  4492.479980  4545.520020  4463.990234  4509.560059
# 4  2016-02-05  4491.479980  4493.189941  4350.370117  4363.140137
#
#      Adj Close      Volume
# 0  4620.370117  1983340000
# 1  4516.950195  2185180000
# 2  4504.240234  2466190000
# 3  4509.560059  2200930000
# 4  4363.140137  2489280000

# %%
df["crecimiento"] = df["Close"]-df["Open"]

# %%
df.head()
# Out:
#          Date         Open         High          Low        Close  \
# 0  2016-02-01  4587.589844  4636.930176  4565.370117  4620.370117
# 1  2016-02-02  4588.689941  4589.899902  4503.120117  4516.950195
# 2  2016-02-03  4543.819824  4547.319824  4424.470215  4504.240234
# 3  2016-02-04  4492.479980  4545.520020  4463.990234  4509.560059
# 4  2016-02-05  4491.479980  4493.189941  4350.370117  4363.140137
#
#      Adj Close      Volume  crecimiento
# 0  4620.370117  1983340000    32.780273
# 1  4516.950195  2185180000   -71.739746
# 2  4504.240234  2466190000   -39.579590
# 3  4509.560059  2200930000    17.080079
# 4  4363.140137  2489280000  -128.339843

# %%
df["%"]= (df["crecimiento"]*100)/df["Close"]

# %%
df.head()
# Out:
#          Date         Open         High          Low        Close  \
# 0  2016-02-01  4587.589844  4636.930176  4565.370117  4620.370117
# 1  2016-02-02  4588.689941  4589.899902  4503.120117  4516.950195
# 2  2016-02-03  4543.819824  4547.319824  4424.470215  4504.240234
# 3  2016-02-04  4492.479980  4545.520020  4463.990234  4509.560059
# 4  2016-02-05  4491.479980  4493.189941  4350.370117  4363.140137
#
#      Adj Close      Volume  crecimiento         %
# 0  4620.370117  1983340000    32.780273  0.709473
# 1  4516.950195  2185180000   -71.739746 -1.588234
# 2  4504.240234  2466190000   -39.579590 -0.878718
# 3  4509.560059  2200930000    17.080079  0.378753
# 4  4363.140137  2489280000  -128.339843 -2.941456

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df = df[["Date","Open","Close","crecimiento","%"]]

# %%
df.head()
# Out:
#         Date         Open        Close  crecimiento         %
# 0 2016-02-01  4587.589844  4620.370117    32.780273  0.709473
# 1 2016-02-02  4588.689941  4516.950195   -71.739746 -1.588234
# 2 2016-02-03  4543.819824  4504.240234   -39.579590 -0.878718
# 3 2016-02-04  4492.479980  4509.560059    17.080079  0.378753
# 4 2016-02-05  4491.479980  4363.140137  -128.339843 -2.941456

# %%
df.to_csv('nasdaq_clean.csv', index=False,)
