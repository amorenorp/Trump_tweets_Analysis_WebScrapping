# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import json

# %%
import requests

url = "https://apidojo-yahoo-finance-v1.p.rapidapi.com/stock/get-histories"

querystring = {"symbol":"NDX","from":"1451639346","to":"1609459140","events":"div","interval":"1d","region":"US"}

headers = {
    'x-rapidapi-key': "74109fba25msh3bbdaa715fc107bp14deafjsn8b76a93e5090",
    'x-rapidapi-host': "apidojo-yahoo-finance-v1.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"chart":{"result":[{"meta":{"currency":null,"symbol":"NDX","exchangeName":"YHD","instrumentType":"MUTUALFUND","firstTradeDate":476029800,"regularMarketTime":1561759658,"gmtoffset":-18000,"timezone":"EST","exchangeTimezoneName":"America/New_York","chartPreviousClose":4593.27,"priceHint":2,"currentTradingPeriod":{"pre":{"timezone":"EST","start":1611910800,"end":1611930600,"gmtoffset":-18000},"regular":{"timezone":"EST","start":1611930600,"end":1611954000,"gmtoffset":-18000},"post":{"timezone":"EST","start":1611954000,"end":1611968400,"gmtoffset":-18000}},"dataGranularity":"1d","range":"","validRanges":["1mo","3mo","6mo","ytd","1y","2y","5y","10y","max"]},"timestamp":[1451917800,1452004200,1452090600,1452177000,1452263400,1452522600,1452609000,1452695400,1452781800,1452868200,1453213800,1453300200,1453386600,1453473000,1453732200,1453818600,1453905000,1453991400,1454077800,1454337000,1454423400,1454509800,1454596200,1454682600,1454941800,1455028200,1455114600,1455201000,1455287400,1455
# ...

# %%
info = response.json()

# %%
info
# Out:
# {'chart': {'result': [{'meta': {'currency': None,
#      'symbol': 'NDX',
#      'exchangeName': 'YHD',
#      'instrumentType': 'MUTUALFUND',
#      'firstTradeDate': 476029800,
#      'regularMarketTime': 1561759658,
#      'gmtoffset': -18000,
#      'timezone': 'EST',
#      'exchangeTimezoneName': 'America/New_York',
#      'chartPreviousClose': 4593.27,
#      'priceHint': 2,
#      'currentTradingPeriod': {'pre': {'timezone': 'EST',
#        'start': 1611910800,
#        'end': 1611930600,
#        'gmtoffset': -18000},
#       'regular': {'timezone': 'EST',
#        'start': 1611930600,
#        'end': 1611954000,
#        'gmtoffset': -18000},
#       'post': {'timezone': 'EST',
#        'start': 1611954000,
#        'end': 1611968400,
#        'gmtoffset': -18000}},
#      'dataGranularity': '1d',
#      'range': '',
#      'validRanges': ['1mo',
#       '3mo',
#       '6mo',
#       'ytd',
#       '1y',
#       '2y',
#       '5y',
#       '10y',
#       'max']},
# ...

# %%
type(info)
# Out:
# dict

# %%
info.keys()
# Out:
# dict_keys(['chart'])

# %%
info.values()
# Out:
# dict_values([{'result': [{'meta': {'currency': None, 'symbol': 'NDX', 'exchangeName': 'YHD', 'instrumentType': 'MUTUALFUND', 'firstTradeDate': 476029800, 'regularMarketTime': 1561759658, 'gmtoffset': -18000, 'timezone': 'EST', 'exchangeTimezoneName': 'America/New_York', 'chartPreviousClose': 4593.27, 'priceHint': 2, 'currentTradingPeriod': {'pre': {'timezone': 'EST', 'start': 1611910800, 'end': 1611930600, 'gmtoffset': -18000}, 'regular': {'timezone': 'EST', 'start': 1611930600, 'end': 1611954000, 'gmtoffset': -18000}, 'post': {'timezone': 'EST', 'start': 1611954000, 'end': 1611968400, 'gmtoffset': -18000}}, 'dataGranularity': '1d', 'range': '', 'validRanges': ['1mo', '3mo', '6mo', 'ytd', '1y', '2y', '5y', '10y', 'max']}, 'timestamp': [1451917800, 1452004200, 1452090600, 1452177000, 1452263400, 1452522600, 1452609000, 1452695400, 1452781800, 1452868200, 1453213800, 1453300200, 1453386600, 1453473000, 1453732200, 1453818600, 1453905000, 1453991400, 1454077800, 1454337000, 1454423400, 
# ...
